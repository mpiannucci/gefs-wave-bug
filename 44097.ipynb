# %%
import cf_xarray
import gribberish
import xarray as xr

ds = xr.open_dataset("./gefs.wave.t06z.mean.global.0p25.f003.grib2", engine="gribberish")
ds
# Out:
# /Users/matthew/Developer/gefs-bug/.venv/lib/python3.11/site-packages/gribberish/gribberish_backend.py:50: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   return xr.Dataset(
# <xarray.Dataset> Size: 83MB
# Dimensions:    (time: 1, latitude: 721, longitude: 1440)
# Coordinates:
#   * time       (time) datetime64[ns] 8B 2024-05-12T09:00:00
#   * latitude   (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
# Data variables:
#     swell      (time, latitude, longitude) float64 8MB ...
# ...
